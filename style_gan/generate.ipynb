# %%
# !pip install Pillow==6.2.1

# %%
pip install ninja
# Out:
# ...
#      |████████████████████████████████| 112kB 7.4MB/s
# ...

# %%
# clone repo with edited generate.py script to fenerate grey scale images for training
# !git clone https://github.com/dariadiatlova/data-efficient-gans
# Out:
# Cloning into 'data-efficient-gans'...
# remote: Enumerating objects: 704, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 704 (delta 106), reused 103 (delta 103), pack-reused 586
# Receiving objects: 100% (704/704), 34.73 MiB | 23.87 MiB/s, done.
# Resolving deltas: 100% (381/381), done.

# %%
cd data-efficient-gans/DiffAugment-stylegan2-pytorch
# Out:
# /content/data-efficient-gans/DiffAugment-stylegan2-pytorch

# %%
# !python3 generate.py --outdir='/content/drive/MyDrive/hse/DL/Data-Diff-GAN/generated_4k_90' --seeds=0-4000 --network='/content/drive/MyDrive/hse/DL/Data-Diff-GAN/results/00001-disgust-low_shot-kimg90-color-translation-cutout/network-snapshot-000090.pkl'
# Out:
# Loading networks from "/content/drive/MyDrive/hse/DL/Data-Diff-GAN/results/00001-disgust-low_shot-kimg90-color-translation-cutout/network-snapshot-000090.pkl"...
# Generating image for seed 0 (0/4001) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1 (1/4001) ...
# Generating image for seed 2 (2/4001) ...
# Generating image for seed 3 (3/4001) ...
# Generating image for seed 4 (4/4001) ...
# Generating image for seed 5 (5/4001) ...
# Generating image for seed 6 (6/4001) ...
# Generating image for seed 7 (7/4001) ...
# Generating image for seed 8 (8/4001) ...
# Generating image for seed 9 (9/4001) ...
# Generating image for seed 10 (10/4001) ...
# Generating image for seed 11 (11/4001) ...
# Generating image for seed 12 (12/4001) ...
# Generating image for seed 13 (13/4001) ...
# Generating image for seed 14 (14/4001) ...
# Generating image for seed 15 (15/4001) ...
# ...
